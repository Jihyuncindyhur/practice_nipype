# %% [markdown]
# ## **JoinNode, synchronize and itersource**
#
# `JoinNode` has the opposite effects of iterables:
#
#     * iterables: split up the execution workflow into many different branches
#     * JoinNode: merges different branches back into one node
#
# JoinNode generalizes `MapNode` to operate in conjuction with an upstream iterable node to reassemble downstream results. <br>
# : 멥노드랑 비슷한데, 이건 MapNode를 좀 더 일반화/확장 시킴 (윗 부분엔 iterable node 처럼, 밑에서는 다시 결과값을 모을 수 있을 수 있도록)

# %% [markdown]
# ### **Example**

# %% [markdown]
# ```python
#
# from nipype import Node, JoinNode, Workflow
#
# a = Node(interface=A(), name="a")
# b = Node(interface=B(), name="b")
# b.iterables = ('in_file', [file1, file2])
#
# c = Node(interface=C(), name="c")
# d = JoinNode(interface=D(),
#              joinsource="b",
#              joinfield="in_files",
#              name="d")
#
# workflow = Workflow(name="workflow")
# workflow.connect([(a, b, [('subject', 'subject')]),
#                   (b, c, [('out_file', 'in_file')])
#                   (c, d, [('out_file', 'in_files')])
#                   ])
# ```
#
# `Joinsource`: from which node the info to join in coming
# `Joinfield` : the input field of the JoinNode where the info to join will be entering the node (input of the JoinNode)
#
# This example assumes that interface A has one output *subject*, interface B has two inputs *subject* and *in_file*, and one output *out_file*, interface C has one input *in_file* and one output *out_file*, and interface D has one list input *in_files*.
#
# In this example, the node c *out_file* outputs are collected into the JoinNode D *in_files* input list. The *in_files* order is the same as the upstream B node iterables order.
#
# The JoinNode input can be filtered for unique values by specifying the *unique* flag, e.g:
# ```python
# d = JoinNode(interface=D(),
#              joinsource="b",
#              unique=True,
#              name="d")
# ```

# %% [markdown]
# ### **`synchronize`**
# : 리스트에서 같은 자리에 있는 애들끼리 묶어서 input으로 넣기
#
# The `Node iterables` parameter can be a single field or a list of fields. If it is a list, then execution is performed over all permutations of the list items.
#
# ```python
# b.iterables = [("m", [1, 2]), ("n", [3, 4])]
# ```
#
# The results will be four iterables: 13 (m=1, n=3), 14, 23, 24
#
# The `synchronize` parameter synchronizes the iterables lists, e.g.:
# ```python
# b.iterables = [("m", [1, 2], ("n"), [3, 4])]
# b.synchronize = True
# ```
# where the iterable inputs are selected in lock-step by index, i.e.:
#
#     (*m*, *n*) = (1, 3) and (2, 4)

# %% [markdown]
# ## **`itersource`**
#
# The `itersource` feature allows you to expand a downstream `iterable` based on a mapping of an upstream `iterable`.
#
# ```python
# a = Node(interface=A(), name="a")
# b = Node(interface=B(), name="b")
# b.iterables = ("m", [1, 2])
#
# c = Node(interface=C(), name="c")
# d = Node(interface=D(), name="d")
# d.itersource = ("b", "m") #b? m?
# d.iterables = [("n", {1:[3,4], 2:[5,6]})]
# my_workflow = Workflow(name="my_workflow")
# my_workflow.connect([(a,b,[('out_file','in_file')]),
#                      (b,c,[('out_file','in_file')])
#                      (c,d,[('out_file','in_file')])
#                      ])
#
# e = JoinNode(interface=E(), joinsource="d",
#              joinfield="in_files", name="e")
# my_workflow.connect(d, 'out_file',
#                     e, 'in_files')
#
# ```

# %% [markdown]
# ## **More realistic `JoinNode` example**
#
# Let's consider another example where we have one node that iterates over 3 different numbers and generates random numbers. Another node joins those three different numbers (each coming from a separate branch of the workflow) into one list. To make the whole thing a bit more realistic, the second node will use the Function interface to do something with those numbers, before we spit them out again.

# %%
from nipype import JoinNode, Node, Workflow
from nipype.interfaces.utility import Function, IdentityInterface

def get_data_from_id(id):
    """Generate a random number based on id"""
    import numpy as np
    return id + np.random.rand()

def merge_and_scale_data(data2):
    """Scale the input list by 1000"""
    import numpy as np
    return (np.array(data2) * 1000).tolist()

node1 = Node(Function(['id'], ['data1'], get_data_from_id), name='get_data')
node1.iterables = ('id', [1, 2, 3])

node2 = JoinNode(Function(['data2'], ['data_scaled'], merge_and_scale_data), 
                 name='scale_data',
                 joinsource=node1,
                 joinfield=['data2'])

wf = Workflow(name='testjoin')
wf.connect(node1, 'data1', node2, 'data2')
eg = wf.run()
# Out:
# 190207-07:39:25,553 nipype.workflow INFO:
# 	 Workflow testjoin settings: ['check', 'execution', 'logging', 'monitoring']
# 190207-07:39:25,585 nipype.workflow INFO:
# 	 Running serially.
# 190207-07:39:25,588 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.get_data" in "/tmp/tmp7_f37ort/testjoin/_id_3/get_data".
# 190207-07:39:25,595 nipype.workflow INFO:
# 	 [Node] Running "get_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:39:25,604 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.get_data".
# 190207-07:39:25,607 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.get_data" in "/tmp/tmp2bh612u7/testjoin/_id_2/get_data".
# 190207-07:39:25,614 nipype.workflow INFO:
# 	 [Node] Running "get_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:39:25,624 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.get_data".
# 190207-07:39:25,627 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.get_data" in "/tmp/tmpe66bz_1n/testjoin/_id_1/get_data".
# 190207-07:39:25,634 nipype.workflow INFO:
# 	 [Node] Running "get_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:39:25,642 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.get_data".
# 190207-07:39:25,645 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.scale_data" in "/tmp/tmpmu2enox2/testjoin/scale_data".
# 190207-07:39:25,649 nipype.workflow INFO:
# 	 [Node] Running "scale_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:39:25,655 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.scale_data".

# %%
wf.write_graph(graph2use='exec')
from IPython.display import Image
Image(filename='graph_detailed.png')
# Out:
# 190207-07:39:28,193 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/Practices/Basics/graph.png (graph2use=exec, simple_form=True).

# %%
res = [node for node in eg.nodes() if 'scale_data' in node.name][0].result
res.outputs
# Out:
# data_scaled = [1503.3308767727453, 2039.629278743078, 3566.980180305821]

# %%
res.inputs
# Out:
# {'function_str': 'def merge_and_scale_data(data2):\n    """Scale the input list by 1000"""\n    import numpy as np\n    return (np.array(data2) * 1000).tolist()\n',
#  'data2': [1.5033308767727454, 2.039629278743078, 3.566980180305821]}

# %% [markdown]
# ## **Extending to multiple nodes**
#
# We extend the workflow by using three nodes. Note that even this workflow, the joinsource corresponds to the node containing iterables and the joinfield corresponds to the input port of the JoinNode that aggregates the iterable branches. As before the graph below shows how the execution process is set up.

# %%
def get_data_from_id(id):
    import numpy as np
    return id + np.random.rand()

def scale_data(data2):
    import numpy as np
    return data2

def replicate(data3, nreps=2):
    return data3 * nreps

node1 = Node(Function(input_names=['id'],
                      output_names=['data1'],
                      function=get_data_from_id),
             name='get_data')
node1.iterables = ('id', [1, 2, 3])

node2 = Node(Function(input_names=['data2'],
                      output_names=['data_scaled'],
                      function=scale_data),
             name='scale_data')

node3 = JoinNode(Function(input_names=['data3'],
                          output_names=['data_repeated'],
                          function=replicate),
                 name='replicate_data',
                 joinsource=node1,
                 joinfield=['data3'])

wf = Workflow(name='testjoin')
wf.connect(node1, 'data1', node2, 'data2')
wf.connect(node2, 'data_scaled', node3, 'data3')
eg = wf.run()
# Out:
# 190207-07:42:00,8 nipype.workflow INFO:
# 	 Workflow testjoin settings: ['check', 'execution', 'logging', 'monitoring']
# 190207-07:42:00,43 nipype.workflow INFO:
# 	 Running serially.
# 190207-07:42:00,45 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.get_data" in "/tmp/tmpj55b_997/testjoin/_id_3/get_data".
# 190207-07:42:00,52 nipype.workflow INFO:
# 	 [Node] Running "get_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:42:00,62 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.get_data".
# 190207-07:42:00,64 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.scale_data" in "/tmp/tmps8cajf9s/testjoin/_id_3/scale_data".
# 190207-07:42:00,70 nipype.workflow INFO:
# 	 [Node] Running "scale_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:42:00,79 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.scale_data".
# 190207-07:42:00,81 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.get_data" in "/tmp/tmpsdj2lshh/testjoin/_id_2/get_data".
# 190207-07:42:00,87 nipype.workflow INFO:
# 	 [Node] Running "get_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:42:00,96 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.get_data".
# 190207-07:42:00,99 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.scale_data" in "/tmp/tmpik3m1o0q/testjoin/_id_2/scale_data".
# 190207-07:42:00,105 nipype.workflow INFO:
# 	 [Node] Running "scale_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:42:00,114 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.scale_data".
# 190207-07:42:00,116 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.get_data" in "/tmp/tmpf8w70qir/testjoin/_id_1/get_data".
# 190207-07:42:00,125 nipype.workflow INFO:
# 	 [Node] Running "get_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:42:00,138 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.get_data".
# 190207-07:42:00,142 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.scale_data" in "/tmp/tmpc_esrazt/testjoin/_id_1/scale_data".
# 190207-07:42:00,153 nipype.workflow INFO:
# 	 [Node] Running "scale_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:42:00,159 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.scale_data".
# 190207-07:42:00,162 nipype.workflow INFO:
# 	 [Node] Setting-up "testjoin.replicate_data" in "/tmp/tmpv5grl2nw/testjoin/replicate_data".
# 190207-07:42:00,168 nipype.workflow INFO:
# 	 [Node] Running "replicate_data" ("nipype.interfaces.utility.wrappers.Function")
# 190207-07:42:00,177 nipype.workflow INFO:
# 	 [Node] Finished "testjoin.replicate_data".

# %%
wf.write_graph(graph2use='exec')
Image(filename='graph_detailed.png')
# Out:
# 190207-07:42:09,242 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/Practices/Basics/graph.png (graph2use=exec, simple_form=True).
